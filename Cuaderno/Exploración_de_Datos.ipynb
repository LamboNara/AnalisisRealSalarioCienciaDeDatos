# %% [markdown]
# # **Extracción de Datos**

# %%
#Importación módulos
import pandas as pd
import seaborn as sns
import matplotlib as plt
import matplotlib.pyplot as plt

#Importación csv
archivo = pd.read_csv("https://drive.google.com/uc?id=1Bl6P4csc7Swwh8t8GNF2KZMVNxn72m3a")
archivo.head()
# Out:
#    Unnamed: 0  work_year experience_level employment_type  \
# 0           0       2020               MI              FT
# 1           1       2020               SE              FT
# 2           2       2020               SE              FT
# 3           3       2020               MI              FT
# 4           4       2020               SE              FT
#
#                     job_title  salary salary_currency  salary_in_usd  \
# 0              Data Scientist   70000             EUR          79833
# 1  Machine Learning Scientist  260000             USD         260000
# 2           Big Data Engineer   85000             GBP         109024
# 3        Product Data Analyst   20000             USD          20000
# 4   Machine Learning Engineer  150000             USD         150000
#
#   employee_residence  remote_ratio company_location company_size
# 0                 DE             0               DE            L
# 1                 JP             0               JP            S
# 2                 GB            50               GB            M
# 3                 HN             0               HN            S
# 4                 US            50               US            L

# %% [markdown]
# # **Exploracción y transformación de Datos**

# %%
df= archivo.drop(columns= "Unnamed: 0")
df
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 3         2020               MI              FT        Product Data Analyst
# 4         2020               SE              FT   Machine Learning Engineer
# ..         ...              ...             ...                         ...
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
# 606       2022               MI              FT                AI Scientist
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0     70000             EUR          79833                 DE             0
# 1    260000             USD         260000                 JP             0
# 2     85000             GBP         109024                 GB            50
# 3     20000             USD          20000                 HN             0
# 4    150000             USD         150000                 US            50
# ..      ...             ...            ...                ...           ...
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
# 606  200000             USD         200000                 IN           100
#
#     company_location company_size
# 0                 DE            L
# 1                 JP            S
# 2                 GB            M
# 3                 HN            S
# 4                 US            L
# ..               ...          ...
# 602               US            M
# 603               US            M
# 604               US            M
# 605               US            M
# 606               US            L
#
# [607 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 607 entries, 0 to 606
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   work_year           607 non-null    int64
#  1   experience_level    607 non-null    object
#  2   employment_type     607 non-null    object
#  3   job_title           607 non-null    object
#  4   salary              607 non-null    int64
#  5   salary_currency     607 non-null    object
#  6   salary_in_usd       607 non-null    int64
#  7   employee_residence  607 non-null    object
#  8   remote_ratio        607 non-null    int64
#  9   company_location    607 non-null    object
#  10  company_size        607 non-null    object
# dtypes: int64(4), object(7)
# memory usage: 52.3+ KB

# %% [markdown]
# No hay missing values o datos nulos dentro de nuestro dataset. No es necesario utilizar técnicas de rellenamiento de datos.

# %%
df.duplicated().sum()
# Out:
# 42

# %% [markdown]
# # **Análisis exploratorio de datos**

# %% [markdown]
# ## **Posición de trabajo más frecuente**

# %%
sns.countplot(y="job_title", data=df, orient="h",)
sns.set(rc={'figure.figsize':(25,25)})
plt.ylabel('Titulo de trabajos')
plt.xlabel('Frecuencia')
plt.title('Frecuencia de los trabajos', y=1.01);

# %%
df['job_title'].value_counts()[:15]
# Out:
# Data Scientist                143
# Data Engineer                 132
# Data Analyst                   97
# Machine Learning Engineer      41
# Research Scientist             16
# Data Science Manager           12
# Data Architect                 11
# Big Data Engineer               8
# Machine Learning Scientist      8
# Principal Data Scientist        7
# AI Scientist                    7
# Data Science Consultant         7
# Director of Data Science        7
# Data Analytics Manager          7
# ML Engineer                     6
# Name: job_title, dtype: int64

# %% [markdown]
# El trabajo de Data Scientist es el más frecuente.

# %% [markdown]
# ## **Tiempo de empleo más popular en el área de la ciencia de datos**

# %%
sns.countplot(x='employment_type', data=df)
sns.set(rc={'figure.figsize':(10,10)})
plt.ylabel('Frecuencia')
plt.xlabel('Tipo de empleo')
plt.title('Frecuencia de tiempo donde mas se emplea', y=1.01);
# FT = Full time CT = Contract PT = Part Time FL = Freelance

# %% [markdown]
# La mayoría de las personas dentro del área de la ciencia de datos trabajan Full time.

# %% [markdown]
# ## **Tipo de trabajo más común en la ciencia de datos**

# %%
sns.countplot(x="remote_ratio", data=df, orient="h",)
sns.set(rc={'figure.figsize':(25,25)})
plt.ylabel('Frecuencia')
plt.xlabel('Tipo de trabajo')
plt.title('Conteo de personas en cada tipo de categoría de trabajo', y=1.01);

# %% [markdown]
# A partir de este gráfico vemos que en el área de la ciencia de datos los trabajos más comunes son los Totalmente Remotos

# %% [markdown]
# ## **Cantidad de trabajos en el área de la ciencia de datos a través de los años**

# %%
sns.countplot(x='work_year', data=df)
sns.set(rc={'figure.figsize':(10,10)})
plt.ylabel('Frecuencia')
plt.xlabel('Trabajo año')
plt.title('Frecuencia de diferente tipo de Cientificos de datos en los años', y=1.01)
# Out:
# Text(0.5, 1.01, 'Frecuencia de diferente tipo de Cientificos de datos en los años')

# %% [markdown]
# Está en aumento los trabajos relacionados a la ciencia de datos.

# %% [markdown]
# ## **Salario promedio en base a distintas categorías**

# %%
#Cálculo de salarios promedio
avg_sal_per_job =df.groupby('job_title').mean()['salary_in_usd']
avg_sal_per_experiencie=df.groupby('experience_level').mean()['salary_in_usd']
avg_sal_per_company_size=df.groupby('company_size').mean()['salary_in_usd']
avg_sal_per_remote_work=df.groupby('remote_ratio').mean()['salary_in_usd']
avg_sal_per_employment_type=df.groupby('employment_type').mean()['salary_in_usd']
# Out:
# <ipython-input-15-683fc8a1a70b>:2: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sal_per_job =df.groupby('job_title').mean()['salary_in_usd']
# <ipython-input-15-683fc8a1a70b>:3: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sal_per_experiencie=df.groupby('experience_level').mean()['salary_in_usd']
# <ipython-input-15-683fc8a1a70b>:4: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sal_per_company_size=df.groupby('company_size').mean()['salary_in_usd']
# <ipython-input-15-683fc8a1a70b>:5: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sal_per_remote_work=df.groupby('remote_ratio').mean()['salary_in_usd']
# <ipython-input-15-683fc8a1a70b>:6: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sal_per_employment_type=df.groupby('employment_type').mean()['salary_in_usd']

# %% [markdown]
# ## **Salario promedio por posición de trabajo**

# %%
plt.figure(figsize=(20,20))
sns.barplot(x=avg_sal_per_job.values,y=avg_sal_per_job.index)
plt.xlabel('Promedio de Salario en USD')
plt.ylabel('Titulo del trabajo')
plt.title('Promedio del Salario en los diferentes trabajos de Cientificos de data', y=1.01);

# %% [markdown]
# ## **Salario promedio por nivel de experiencia**

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=avg_sal_per_experiencie.index,y=avg_sal_per_experiencie.values)
plt.xlabel('Nivel de experiencia')
plt.ylabel('Promedio del Salario en Usd')
plt.title('Promedio del salario basado en su nivel de experiencia', y=1.01);

# %% [markdown]
# ## **Salario promedio por tamaño de la compañía**

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=avg_sal_per_company_size.index,y=avg_sal_per_company_size.values)
plt.xlabel('Tamaño de la empresa')
plt.ylabel('Salario promedio')
plt.title('Promedio del salario basado en el tamaño de la empresa', y=1.01);

# %% [markdown]
# ## **Salario promedio por trabajo remoto**

# %%
avg_sal_per_remote_work=df.groupby('remote_ratio').mean()['salary_in_usd']
sns.barplot(x=avg_sal_per_remote_work.index,y=avg_sal_per_remote_work.values)
plt.xlabel('Porcentaje del trabajo remoto')
plt.ylabel('Promedio de salario')
plt.title('Promedio del salario basado en el trabajo remoto', y=1.01);
# Out:
# <ipython-input-20-ef64cfe477bf>:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.mean is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   avg_sal_per_remote_work=df.groupby('remote_ratio').mean()['salary_in_usd']

# %% [markdown]
# ## **Salario promedio por tipo de empleamiento**

# %%
plt.figure(figsize=(10,10))
sns.barplot(x=avg_sal_per_employment_type.index,y=avg_sal_per_employment_type.values)
plt.xlabel('Tipo de empleo')
plt.ylabel('Promedio del salario')
plt.title('Promedio del salario basado en el tipo de empleo', y=1.01);

# %%
sns.catplot(x='company_size', y='salary_in_usd', data=archivo)

# %% [markdown]
# # **Arreglo para análisis predictivo**

# %%
jobtitle = df.groupby('job_title').size().sort_values(ascending = False)
jobtitle.head(10)
# Out:
# job_title
# Data Scientist                143
# Data Engineer                 132
# Data Analyst                   97
# Machine Learning Engineer      41
# Research Scientist             16
# Data Science Manager           12
# Data Architect                 11
# Big Data Engineer               8
# Machine Learning Scientist      8
# Director of Data Science        7
# dtype: int64

# %%
dataset = df.loc[df.job_title.isin(['Data Scientist', 'Data Engineer',"Data Analyst","Machine Learning Engineer","Research Scientist","Data Science Manager","Data Architect","Big Data Engineer","Machine Learning Scientist","Director of Data Science"])]
dataset
# Out:
#      work_year experience_level employment_type                   job_title  \
# 0         2020               MI              FT              Data Scientist
# 1         2020               SE              FT  Machine Learning Scientist
# 2         2020               SE              FT           Big Data Engineer
# 4         2020               SE              FT   Machine Learning Engineer
# 5         2020               EN              FT                Data Analyst
# ..         ...              ...             ...                         ...
# 601       2022               EN              FT                Data Analyst
# 602       2022               SE              FT               Data Engineer
# 603       2022               SE              FT               Data Engineer
# 604       2022               SE              FT                Data Analyst
# 605       2022               SE              FT                Data Analyst
#
#      salary salary_currency  salary_in_usd employee_residence  remote_ratio  \
# 0     70000             EUR          79833                 DE             0
# 1    260000             USD         260000                 JP             0
# 2     85000             GBP         109024                 GB            50
# 4    150000             USD         150000                 US            50
# 5     72000             USD          72000                 US           100
# ..      ...             ...            ...                ...           ...
# 601   52000             USD          52000                 CA             0
# 602  154000             USD         154000                 US           100
# 603  126000             USD         126000                 US           100
# 604  129000             USD         129000                 US             0
# 605  150000             USD         150000                 US           100
#
#     company_location company_size
# 0                 DE            L
# 1                 JP            S
# 2                 GB            M
# 4                 US            L
# 5                 US            L
# ..               ...          ...
# 601               CA            M
# 602               US            M
# 603               US            M
# 604               US            M
# 605               US            M
#
# [475 rows x 11 columns]

# %%
predictive = dataset.drop(columns=["salary_currency","employee_residence","company_location","salary"],inplace =True)
# Out:
# <ipython-input-27-2e57417ae7dd>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   predictive = dataset.drop(columns=["salary_currency","employee_residence","company_location","salary"],inplace =True)

# %%
predictive = pd.get_dummies(dataset)
predictive
# Out:
#      work_year  salary_in_usd  remote_ratio  experience_level_EN  \
# 0         2020          79833             0                    0
# 1         2020         260000             0                    0
# 2         2020         109024            50                    0
# 4         2020         150000            50                    0
# 5         2020          72000           100                    1
# ..         ...            ...           ...                  ...
# 601       2022          52000             0                    1
# 602       2022         154000           100                    0
# 603       2022         126000           100                    0
# 604       2022         129000             0                    0
# 605       2022         150000           100                    0
#
#      experience_level_EX  experience_level_MI  experience_level_SE  \
# 0                      0                    1                    0
# 1                      0                    0                    1
# 2                      0                    0                    1
# 4                      0                    0                    1
# 5                      0                    0                    0
# ..                   ...                  ...                  ...
# 601                    0                    0                    0
# 602                    0                    0                    1
# 603                    0                    0                    1
# 604                    0                    0                    1
# 605                    0                    0                    1
#
#      employment_type_FL  employment_type_FT  employment_type_PT  ...  \
# 0                     0                   1                   0  ...
# 1                     0                   1                   0  ...
# 2                     0                   1                   0  ...
# 4                     0                   1                   0  ...
# 5                     0                   1                   0  ...
# ..                  ...                 ...                 ...  ...
# 601                   0                   1                   0  ...
# 602                   0                   1                   0  ...
# 603                   0                   1                   0  ...
# 604                   0                   1                   0  ...
# 605                   0                   1                   0  ...
#
#      job_title_Data Engineer  job_title_Data Science Manager  \
# 0                          0                               0
# 1                          0                               0
# 2                          0                               0
# 4                          0                               0
# 5                          0                               0
# ..                       ...                             ...
# 601                        0                               0
# 602                        1                               0
# 603                        1                               0
# 604                        0                               0
# 605                        0                               0
#
#      job_title_Data Scientist  job_title_Director of Data Science  \
# 0                           1                                   0
# 1                           0                                   0
# 2                           0                                   0
# 4                           0                                   0
# 5                           0                                   0
# ..                        ...                                 ...
# 601                         0                                   0
# 602                         0                                   0
# 603                         0                                   0
# 604                         0                                   0
# 605                         0                                   0
#
#      job_title_Machine Learning Engineer  \
# 0                                      0
# 1                                      0
# 2                                      0
# 4                                      1
# 5                                      0
# ..                                   ...
# 601                                    0
# 602                                    0
# 603                                    0
# 604                                    0
# 605                                    0
#
#      job_title_Machine Learning Scientist  job_title_Research Scientist  \
# 0                                       0                             0
# 1                                       1                             0
# 2                                       0                             0
# 4                                       0                             0
# 5                                       0                             0
# ..                                    ...                           ...
# 601                                     0                             0
# 602                                     0                             0
# 603                                     0                             0
# 604                                     0                             0
# 605                                     0                             0
#
#      company_size_L  company_size_M  company_size_S
# 0                 1               0               0
# 1                 0               0               1
# 2                 0               1               0
# 4                 1               0               0
# 5                 1               0               0
# ..              ...             ...             ...
# 601               0               1               0
# 602               0               1               0
# 603               0               1               0
# 604               0               1               0
# 605               0               1               0
#
# [475 rows x 23 columns]

# %%
predictive.columns.values
# Out:
# array(['work_year', 'salary_in_usd', 'remote_ratio',
#        'experience_level_EN', 'experience_level_EX',
#        'experience_level_MI', 'experience_level_SE', 'employment_type_FL',
#        'employment_type_FT', 'employment_type_PT',
#        'job_title_Big Data Engineer', 'job_title_Data Analyst',
#        'job_title_Data Architect', 'job_title_Data Engineer',
#        'job_title_Data Science Manager', 'job_title_Data Scientist',
#        'job_title_Director of Data Science',
#        'job_title_Machine Learning Engineer',
#        'job_title_Machine Learning Scientist',
#        'job_title_Research Scientist', 'company_size_L', 'company_size_M',
#        'company_size_S'], dtype=object)

# %% [markdown]
# # **Análisis predictivo**

# %%
yvar = ['salary_in_usd']
Xvars = ['work_year', 'salary_in_usd', 'remote_ratio',
       'experience_level_EN', 'experience_level_EX',
       'experience_level_MI', 'experience_level_SE', 'employment_type_FL',
       'employment_type_FT', 'employment_type_PT',
       'job_title_Big Data Engineer', 'job_title_Data Analyst',
       'job_title_Data Architect', 'job_title_Data Engineer',
       'job_title_Data Science Manager', 'job_title_Data Scientist',
       'job_title_Director of Data Science',
       'job_title_Machine Learning Engineer',
       'job_title_Machine Learning Scientist',
       'job_title_Research Scientist', 'company_size_L', 'company_size_M',
       'company_size_S']

# %%
#Separando las variables
y = predictive[yvar]
X = predictive[Xvars]

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = .2, random_state = 0)

# %% [markdown]
# # **Entrenamiento**

# %%
# Creando el modelo
# from sklearn.linear_model import LinearRegression
# modelo = LinearRegression()

from sklearn import tree
modelo = tree.DecisionTreeRegressor()

# Entrenando el modelo
modelo.fit(X_train, y_train)
# Out:
# DecisionTreeRegressor()

# %% [markdown]
# ## **Evaluación**

# %%
y_eval = modelo.predict(X_test)

# %%
from sklearn.metrics import r2_score

r2 = r2_score(y_test, y_eval)
r2
# Out:
# 0.9996546654932972

# %% [markdown]
# ## **Predicción**

# %%
x_pred = pd.DataFrame({'work_year': [2020],
                       'salary_in_usd': [4000],
                       'remote_ratio' : [0],
                       'experience_level_EN': [0],
                       'experience_level_EX': [1],
                       'experience_level_MI': [0],
                       'experience_level_SE': [0],
                       'employment_type_FL': [0],
                       'employment_type_FT': [0],
                       'employment_type_PT': [1],
                       'job_title_Big Data Engineer': [0],
                       'job_title_Data Analyst': [0],
                       'job_title_Data Architect':[0],
                       'job_title_Data Engineer': [1],
                       'job_title_Data Science Manager': [0],
                       'job_title_Data Scientist': [0],
                       'job_title_Director of Data Science': [0],
                       'job_title_Machine Learning Engineer': [0],
                       'job_title_Machine Learning Scientist': [0],
                       'job_title_Research Scientist': [0],
                       'company_size_L': [0],
                       'company_size_M': [1],
                       'company_size_S': [0],})

y_pred = modelo.predict(x_pred)
y_pred
# Out:
# array([4000.])
